# %%
import os

# %%
# unabstarct = []
text_dir = "/home/mindrank/fuli/itext2kg/Data/AD_pubtabor"

print(len(os.listdir(text_dir)))
for file in os.listdir(text_dir):
    with open(f'{text_dir}/{file}', 'r') as f:
        text_line = f.readlines()
        abstract = text_line[1].strip().split('|')[-1]
    if len(abstract) < 100:
        pmid = file.split('.')[0]
        os.system(
            f'rm -rf {text_dir}/{file}'
        )

print(len(os.listdir(text_dir)))
# Out:
# 355793
# 338338
