# %%
# %load_ext autoreload
# %autoreload 2


import sys
sys.path.append("..")

# %% [markdown]
# The goal of this notebook is to evaluate the triplets returned by iText2KG against human-extracted triplets.
#
# To achieve this, we have enhanced the music and computer science datasets curated by Othmane et al. (Kabal, Othmane, et al. "Enhancing Domain-Independent Knowledge Graph Construction through OpenIE Cleaning and LLMs Validation." International Conference on Knowledge-Based and Intelligent Information & Engineering Systems, 2024) by grouping triplets based on similar sentences and extracting triplets using iText2KG.
#
# Additionally, we incorporated factoids (Chen, Tong, et al. "Dense x retrieval: What retrieval granularity should we use?" arXiv preprint arXiv:2312.06648, 2023) using GPT-4o and re-extracted triplets from these factoids with iText2KG. The aim is to compare triplets extracted from raw documents (using iText2KG) and factoids (using iText2KG) against human-extracted triplets.
#
# There is no need to re-run all cells, as the datasets are available in the datasets/curated folder.

# %% [markdown]
# ## Loading the datasets
# ---

# %%
import pandas as pd 

music = pd.read_excel("GS_Music.xlsx")
cs = pd.read_excel("GS_CS-corpus.xlsx")

# %% [markdown]
# ## LLM Model and Embeddings Model
# ---

# %%
from langchain_openai import ChatOpenAI, OpenAIEmbeddings

openai_api_key = "sk-##"

openai_llm_model = llm = ChatOpenAI(
    api_key = openai_api_key,
    model="gpt-4o",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
)

openai_embeddings_model = OpenAIEmbeddings(
    api_key = openai_api_key ,
    model="text-embedding-3-large",
)

# %%
from itext2kg import iText2KG
# Out:
# c:\Users\yassir.lairgi\Documents\Projects\iText2KG\venv-test\Lib\site-packages\pydantic\_internal\_generate_schema.py:547: UserWarning: <built-in function array> is not a Python type (it may be an instance of an object), Pydantic will allow any object with no validation since we cannot even enforce that the input is an instance of the given type. To get rid of this error wrap the type with `pydantic.SkipValidation`.
#   warn(

# %%
itext2kg = iText2KG(llm_model=openai_llm_model, embeddings_model=openai_embeddings_model)

# %% [markdown]
# ## Preprocessing of the two datasets, grouping the phrases and triplets.
# ---

# %%
# Group by Sentences and aggregate
grouped_cs = cs.groupby('Sentences').agg({
    'Sentences': "first",  # Join sentences with a space
    'Triplet': lambda x: '; '.join(x),  # Join triplets as strings with a semicolon
    'Topic': 'first',  # Keep the first topic
    'Annotator 1': 'first',  # Keep the first annotator
    'Annotator 2': 'first',  # Keep the first annotator
    'Ttiple_id': 'first'  # Keep the first triplet_id
}).reset_index(drop=True)  # Avoid resetting the index with Sentences

# Rename columns to reflect the aggregated data
grouped_cs.rename(columns={
    'Sentences': 'Combined_Sentences',
    'Triplet': 'Combined_Triplets'
}, inplace=True)

# %%
# Group by Sentences and aggregate
music["Triplet"] = music.apply(lambda row: f"({row['Subject']}, {row['Predicate']}, {row['Object']})", axis=1)

grouped_music = music.groupby('Sentences').agg({
    'Sentences': "first",  # Join sentences with a space
    'Triplet': lambda x: '; '.join(x),  # Join triplets as strings with a semicolon
    'Topic': 'first',  # Keep the first topic
    'Annotator 1': 'first',  # Keep the first annotator
    'Annotator 2': 'first',  # Keep the first annotator
    'Triplet_id': 'first'  # Keep the first triplet_id
}).reset_index(drop=True)  # Avoid resetting the index with Sentences

# Rename columns to reflect the aggregated data
grouped_music.rename(columns={
    'Sentences': 'Combined_Sentences',
    'Triplet': 'Combined_Triplets'
}, inplace=True)

# %% [markdown]
# ## Adding factoids for each sentence
# ---

# %%
from itext2kg.documents_distiller import DocumentsDistiller
from pydantic import BaseModel, Field
from typing import List

document_distiller = DocumentsDistiller(llm_model=openai_llm_model)

class SimplePhrase(BaseModel):
    phrase:str= Field(description="Propositions are defined as atomic expressions within text, each encapsulating a distinct factoid and presented in a concise, self-contained natural language format.")

class ListOfSimplePhrases(BaseModel):
    phrases:List[SimplePhrase] = Field(description="All Propositions")

IE_query = '''
        # DIRECTIVES : 
        - Act like an experienced paraphraser.
        - Paraphrase the following context into a list of simple phrases.
    '''
        
# Distill document content with query
def factoid(paragraph:str):
    print("distilling ..")
    distilled_doc = document_distiller.distill(
    documents=[paragraph],
    IE_query=IE_query,
    output_data_structure=ListOfSimplePhrases
)
    return [fact["phrase"] for fact in distilled_doc["phrases"]]

# %%
grouped_music["Factoids"] = grouped_music["Combined_Sentences"].apply(lambda x: factoid(x))
# Out:
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..

# %%
grouped_cs["Factoids"] = grouped_cs["Combined_Sentences"].apply(lambda x: factoid(x))
# Out:
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..
# distilling ..

# %% [markdown]
# ## Triplets from factoids and from original sentences
# ---

# %%
def extract_triplets_from_original_sentences(original_sentences:str):
    kg = itext2kg.build_graph(sections=[original_sentences])
    return [(rel.startEntity.name, rel.name, rel.endEntity.name) for rel in kg.relationships]

def extract_triplets_from_factoids(factoids:str):
    kg = itext2kg.build_graph(sections=[" ".join(factoids)])
    return [(rel.startEntity.name, rel.name, rel.endEntity.name) for rel in kg.relationships]

# %%
grouped_music["Triplets_From_Factoids"] = grouped_music["Factoids"].apply(lambda x: extract_triplets_from_factoids(x))
# Out:
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Methodist', 'label': 'Religious Denomination'}, {'name': 'Holiness', 'label': 'Religious Movement'}, {'name': 'Baptist', 'label': 'Religious Denomination'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'methodist', 'label': 'Religious_Denomination'}, 'endNode': {'name': 'holiness', 'label': 'Religious_Movement'}, 'name': 'is_a_part_of'}, {'startNode': {'name': 'baptist', 'label': 'Religious_Denomination'}, 'endNode': {'name': 'holiness', 'label': 'Religious_Movement'}, 'name': 'is_a_part_of'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Progressive Bluegrass', 'label': 'Genre'}, {'name': 'Electric Instruments', 'label': 'Instrument'}, {'name': 'Rock & Roll', 'label': 'Genre'}, {'name': 'Cadillac Sky', 'label': 'Band'}, {'name': 'Bearfoot', 'label': 'Band'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'progressive bluegrass', 'label': 'Genre'}, 'endNode': {'name': 'electric instruments', 'label': 'Instrument'}, 'name': 'uses'}, {'startNode': {'name': 'progressive bluegrass', 'label': 'Genre'}, 'endNode': {'name': 'rock & roll', 'label': 'Genre'}, 'name': 'incorporates'}, {'startNode': {'name': 'cadillac sky', 'label': 'Band'}, 'endNode': {'name': 'progressive bluegrass', 'label': 'Genre'}, 'name': 'is an example of'}, {'startNode': {'name': 'bearfoot', 'label': 'Band'}, 'endNode': {'name': 'progressive bluegrass', 'label': 'Genre'}, 'name': 'is an example of'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Old-time music', 'label': 'Music Genre'}, {'name': 'Melody', 'label': 'Musical Element'}, {'name': 'Instrument', 'label': 'Musical Component'}, {'name': 'Lead', 'label': 'Musical Role'}, {'name': 'Accompany', 'label': 'Musical Role'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'instrument', 'label': 'Musical_Component'}, 'endNode': {'name': 'melody', 'label': 'Musical_Element'}, 'name': 'plays'}, {'startNode': {'name': 'old time music', 'label': 'Music_Genre'}, 'endNode': {'name': 'instrument', 'label': 'Musical_Component'}, 'name': 'features'}, {'startNode': {'name': 'instrument', 'label': 'Musical_Component'}, 'endNode': {'name': 'lead', 'label': 'Musical_Role'}, 'name': 'may'}, {'startNode': {'name': 'instrument', 'label': 'Musical_Component'}, 'endNode': {'name': 'accompany', 'label': 'Musical_Role'}, 'name': 'may'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Traditional Bluegrass', 'label': 'Music Genre'}, {'name': 'Folk Songs', 'label': 'Music Type'}, {'name': 'Simple Traditional Chord Progressions', 'label': 'Musical Feature'}, {'name': 'Acoustic Instruments', 'label': 'Instrument Type'}, {'name': 'Bill Monroe', 'label': 'Person'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'traditional bluegrass', 'label': 'Music_Genre'}, 'endNode': {'name': 'folk songs', 'label': 'Music_Type'}, 'name': 'features'}, {'startNode': {'name': 'traditional bluegrass', 'label': 'Music_Genre'}, 'endNode': {'name': 'simple traditional chord progressions', 'label': 'Musical_Feature'}, 'name': 'includes'}, {'startNode': {'name': 'traditional bluegrass', 'label': 'Music_Genre'}, 'endNode': {'name': 'acoustic instruments', 'label': 'Instrument_Type'}, 'name': 'uses'}, {'startNode': {'name': 'bill monroe', 'label': 'Person'}, 'endNode': {'name': 'traditional bluegrass', 'label': 'Music_Genre'}, 'name': 'is an example of'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'A Brisk Young Sailor Courted Me', 'label': 'Ballad'}, {'name': 'I Wish My Baby Was Born', 'label': 'Song'}, {'name': 'England', 'label': 'Country'}, {'name': 'North American bluegrass', 'label': 'Music Genre'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'a brisk young sailor courted me', 'label': 'Ballad'}, 'endNode': {'name': 'i wish my baby was born', 'label': 'Song'}, 'name': 'is known as'}, {'startNode': {'name': 'a brisk young sailor courted me', 'label': 'Ballad'}, 'endNode': {'name': 'england', 'label': 'Country'}, 'name': 'originated in'}, {'startNode': {'name': 'i wish my baby was born', 'label': 'Song'}, 'endNode': {'name': 'north american bluegrass', 'label': 'Music_Genre'}, 'name': 'is part of'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Bluegrass gospel', 'label': 'Subgenre'}, {'name': 'Christian lyrics', 'label': 'Feature'}, {'name': 'Soulful harmony singing', 'label': 'Feature'}, {'name': 'Three-part harmonies', 'label': 'Technique'}, {'name': 'Four-part harmonies', 'label': 'Technique'}, {'name': 'Instrumental playing', 'label': 'Feature'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'bluegrass gospel', 'label': 'Subgenre'}, 'endNode': {'name': 'christian lyrics', 'label': 'Feature'}, 'name': 'features'}, {'startNode': {'name': 'bluegrass gospel', 'label': 'Subgenre'}, 'endNode': {'name': 'soulful harmony singing', 'label': 'Feature'}, 'name': 'includes'}, {'startNode': {'name': 'soulful harmony singing', 'label': 'Feature'}, 'endNode': {'name': 'three part harmonies', 'label': 'Technique'}, 'name': 'involves'}, {'startNode': {'name': 'soulful harmony singing', 'label': 'Feature'}, 'endNode': {'name': 'four part harmonies', 'label': 'Technique'}, 'name': 'involves'}, {'startNode': {'name': 'bluegrass gospel', 'label': 'Subgenre'}, 'endNode': {'name': 'instrumental playing', 'label': 'Feature'}, 'name': 'sometimes includes'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'English ballads', 'label': 'Tradition'}, {'name': 'Scottish ballads', 'label': 'Tradition'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'english ballads', 'label': 'Tradition'}, 'endNode': {'name': 'scottish ballads', 'label': 'Tradition'}, 'name': 'include'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'label': 'Music Tradition', 'name': 'Experimental Music'}, {'label': 'Time Period', 'name': 'Mid-20th Century'}, {'label': 'Region', 'name': 'North America'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'experimental music', 'label': 'Music_Tradition'}, 'endNode': {'name': 'north america', 'label': 'Region'}, 'name': 'became popular in'}, {'startNode': {'name': 'experimental music', 'label': 'Music_Tradition'}, 'endNode': {'name': 'mid 20th century', 'label': 'Time_Period'}, 'name': 'started in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Neo-traditional bluegrass', 'label': 'Genre'}, {'name': 'Bluegrass', 'label': 'Genre'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'neo traditional bluegrass', 'label': 'Genre'}, 'endNode': {'name': 'bluegrass', 'label': 'Genre'}, 'name': 'is a development in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Experimental Action', 'label': 'Concept'}, {'name': 'Unforeseen Outcome', 'label': 'Concept'}, {'name': 'John Cage', 'label': 'Person'}, {'name': 'Unpredictable Actions', 'label': 'Concept'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'john cage', 'label': 'Person'}, 'endNode': {'name': 'experimental action', 'label': 'Concept'}, 'name': 'defines'}, {'startNode': {'name': 'experimental action', 'label': 'Concept'}, 'endNode': {'name': 'unforeseen outcome', 'label': 'Concept'}, 'name': 'results in'}, {'startNode': {'name': 'john cage', 'label': 'Person'}, 'endNode': {'name': 'unpredictable actions', 'label': 'Concept'}, 'name': 'interested in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Béla Bartók', 'label': 'Person'}, {'name': 'Traditional Balkanic Tunes', 'label': 'Music Genre'}, {'name': 'Audio Recordings', 'label': 'Technique'}, {'name': 'Ethnological Perspective', 'label': 'Methodology'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'béla bartók', 'label': 'Person'}, 'endNode': {'name': 'audio recordings', 'label': 'Technique'}, 'name': 'focused on'}, {'startNode': {'name': 'béla bartók', 'label': 'Person'}, 'endNode': {'name': 'traditional balkanic tunes', 'label': 'Music_Genre'}, 'name': 'recorded'}, {'startNode': {'name': 'béla bartók', 'label': 'Person'}, 'endNode': {'name': 'ethnological perspective', 'label': 'Methodology'}, 'name': 'analyzed from'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Electronic Instruments', 'label': 'Instrument'}, {'name': 'Olivier Messiaen', 'label': 'Person'}, {'name': '1930s', 'label': 'Time Period'}, {'name': 'Live Performances', 'label': 'Event'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'olivier messiaen', 'label': 'Person'}, 'endNode': {'name': 'electronic instruments', 'label': 'Instrument'}, 'name': 'used'}, {'startNode': {'name': 'electronic instruments', 'label': 'Instrument'}, 'endNode': {'name': 'live performances', 'label': 'Event'}, 'name': 'used in'}, {'startNode': {'name': '1930s', 'label': 'Time_Period'}, 'endNode': {'name': 'electronic instruments', 'label': 'Instrument'}, 'name': 'began being used'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Romantic period', 'label': 'Period'}, {'name': 'musical modifications', 'label': 'Process'}, {'name': 'Berlioz', 'label': 'Person'}, {'name': 'Mahler', 'label': 'Person'}, {'name': '20th century', 'label': 'Period'}, {'name': 'instrumentation', 'label': 'Technique'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'berlioz', 'label': 'Person'}, 'endNode': {'name': 'musical modifications', 'label': 'Process'}, 'name': 'influenced'}, {'startNode': {'name': 'mahler', 'label': 'Person'}, 'endNode': {'name': 'musical modifications', 'label': 'Process'}, 'name': 'influenced'}, {'startNode': {'name': 'romantic period', 'label': 'Period'}, 'endNode': {'name': 'musical modifications', 'label': 'Process'}, 'name': 'saw changes in'}, {'startNode': {'name': '20th century', 'label': 'Period'}, 'endNode': {'name': 'instrumentation', 'label': 'Technique'}, 'name': 'allowed choice of'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Electric Instruments', 'label': 'Musical Device'}, {'name': 'Electronic Instruments', 'label': 'Musical Device'}, {'name': 'Digital Instruments', 'label': 'Musical Device'}, {'name': 'Musical Devices', 'label': 'Musical Device'}, {'name': 'Composers', 'label': 'Person'}, {'name': 'Musicians', 'label': 'Person'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'composers', 'label': 'Person'}, 'endNode': {'name': 'electric instruments', 'label': 'Musical_Device'}, 'name': 'used'}, {'startNode': {'name': 'musicians', 'label': 'Person'}, 'endNode': {'name': 'electronic instruments', 'label': 'Musical_Device'}, 'name': 'used'}, {'startNode': {'name': 'composers', 'label': 'Person'}, 'endNode': {'name': 'digital instruments', 'label': 'Musical_Device'}, 'name': 'used'}, {'startNode': {'name': 'musicians', 'label': 'Person'}, 'endNode': {'name': 'musical devices', 'label': 'Musical_Device'}, 'name': 'used'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Neoclassicism', 'label': 'Art Movement'}, {'name': '1920s', 'label': 'Time Period'}, {'name': 'Igor Stravinsky', 'label': 'Person'}, {'name': 'Mavra', 'label': 'Opera Buffa'}, {'name': '1922', 'label': 'Year'}, {'name': 'Oedipus Rex', 'label': 'Opera-Oratorio'}, {'name': '1927', 'label': 'Year'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'neoclassicism', 'label': 'Art_Movement'}, 'endNode': {'name': '1920s', 'label': 'Time_Period'}, 'name': 'became popular in'}, {'startNode': {'name': 'mavra', 'label': 'Opera_Buffa'}, 'endNode': {'name': '1922', 'label': 'Year'}, 'name': 'was created in'}, {'startNode': {'name': 'oedipus rex', 'label': 'Opera_Oratorio'}, 'endNode': {'name': '1927', 'label': 'Year'}, 'name': 'was created in'}, {'startNode': {'name': 'igor stravinsky', 'label': 'Person'}, 'endNode': {'name': 'mavra', 'label': 'Opera_Buffa'}, 'name': 'created'}, {'startNode': {'name': 'igor stravinsky', 'label': 'Person'}, 'endNode': {'name': 'oedipus rex', 'label': 'Opera_Oratorio'}, 'name': 'created'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Bluegrass music', 'label': 'Music Genre'}, {'name': 'Fans', 'label': 'Audience'}, {'name': 'Global audience', 'label': 'Audience'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'bluegrass music', 'label': 'Music_Genre'}, 'endNode': {'name': 'global audience', 'label': 'Audience'}, 'name': 'has'}, {'startNode': {'name': 'bluegrass music', 'label': 'Music_Genre'}, 'endNode': {'name': 'fans', 'label': 'Audience'}, 'name': 'has'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Bluegrass music', 'label': 'Genre'}, {'name': 'American roots music', 'label': 'Genre'}, {'name': 'Country music', 'label': 'Genre'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'bluegrass music', 'label': 'Genre'}, 'endNode': {'name': 'american roots music', 'label': 'Genre'}, 'name': 'is a type of'}, {'startNode': {'name': 'bluegrass music', 'label': 'Genre'}, 'endNode': {'name': 'country music', 'label': 'Genre'}, 'name': 'is related to'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Bill Monroe', 'label': 'Person'}, {'name': 'Bluegrass music', 'label': 'Genre'}, {'name': 'Scottish bagpipes', 'label': 'Instrument'}, {'name': 'Old-time fiddling', 'label': 'Technique'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'bill monroe', 'label': 'Person'}, 'endNode': {'name': 'bluegrass music', 'label': 'Genre'}, 'name': 'pioneer of'}, {'startNode': {'name': 'bluegrass music', 'label': 'Genre'}, 'endNode': {'name': 'scottish bagpipes', 'label': 'Instrument'}, 'name': 'mix of'}, {'startNode': {'name': 'bluegrass music', 'label': 'Genre'}, 'endNode': {'name': 'old time fiddling', 'label': 'Technique'}, 'name': 'mix of'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Muddy Waters', 'label': 'Person'}, {'name': 'Delta Blues', 'label': 'Music Genre'}, {'name': 'Mississippi Delta', 'label': 'Region'}, {'name': 'Chicago', 'label': 'City'}, {'name': 'Chicago Blues', 'label': 'Music Genre'}, {'name': 'Acoustic Instruments', 'label': 'Instrument Type'}, {'name': 'Electric Instruments', 'label': 'Instrument Type'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'muddy waters', 'label': 'Person'}, 'endNode': {'name': 'delta blues', 'label': 'Music_Genre'}, 'name': 'played'}, {'startNode': {'name': 'delta blues', 'label': 'Music_Genre'}, 'endNode': {'name': 'mississippi delta', 'label': 'Region'}, 'name': 'originated in'}, {'startNode': {'name': 'delta blues', 'label': 'Music_Genre'}, 'endNode': {'name': 'acoustic instruments', 'label': 'Instrument_Type'}, 'name': 'mostly played with'}, {'startNode': {'name': 'blues musicians', 'label': 'Person'}, 'endNode': {'name': 'mississippi delta', 'label': 'Region'}, 'name': 'moved from'}, {'startNode': {'name': 'blues musicians', 'label': 'Person'}, 'endNode': {'name': 'chicago', 'label': 'City'}, 'name': 'moved to'}, {'startNode': {'name': 'chicago blues', 'label': 'Music_Genre'}, 'endNode': {'name': 'chicago', 'label': 'City'}, 'name': 'formed in'}, {'startNode': {'name': 'chicago blues', 'label': 'Music_Genre'}, 'endNode': {'name': 'electric instruments', 'label': 'Instrument_Type'}, 'name': 'used more'}]}
# [INFO] Verification of invented entities
# [INFO][INVENTED ENTITIES] Aie; the entities label='Person' name='blues musicians' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO] Wohoo! Entity was matched --- [blues musicians:Person] --merged--> [muddy waters:Person]
# [INFO][INVENTED ENTITIES] Aie; the entities label='Person' name='blues musicians' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO] Wohoo! Entity was matched --- [blues musicians:Person] --merged--> [muddy waters:Person]
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Breakdowns', 'label': 'Music Technique'}, {'name': 'Fast Tempos', 'label': 'Musical Characteristic'}, {'name': 'Unusual Instrumental Skill', 'label': 'Musical Skill'}, {'name': 'Complex Chord Changes', 'label': 'Musical Structure'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'breakdowns', 'label': 'Music_Technique'}, 'endNode': {'name': 'fast tempos', 'label': 'Musical_Characteristic'}, 'name': 'often have'}, {'startNode': {'name': 'breakdowns', 'label': 'Music_Technique'}, 'endNode': {'name': 'unusual instrumental skill', 'label': 'Musical_Skill'}, 'name': 'show'}, {'startNode': {'name': 'breakdowns', 'label': 'Music_Technique'}, 'endNode': {'name': 'complex chord changes', 'label': 'Musical_Structure'}, 'name': 'sometimes include'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Busoni', 'label': 'Person'}, {'name': 'Stravinsky', 'label': 'Person'}, {'name': 'Schoenberg', 'label': 'Person'}, {'name': 'Schreker', 'label': 'Person'}, {'name': 'Ives', 'label': 'Person'}, {'name': 'Modernism', 'label': 'Movement'}, {'name': 'Tonality', 'label': 'Concept'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'busoni', 'label': 'Person'}, 'endNode': {'name': 'modernism', 'label': 'Movement'}, 'name': 'recognized as'}, {'startNode': {'name': 'stravinsky', 'label': 'Person'}, 'endNode': {'name': 'modernism', 'label': 'Movement'}, 'name': 'recognized as'}, {'startNode': {'name': 'schoenberg', 'label': 'Person'}, 'endNode': {'name': 'modernism', 'label': 'Movement'}, 'name': 'recognized as'}, {'startNode': {'name': 'schreker', 'label': 'Person'}, 'endNode': {'name': 'modernism', 'label': 'Movement'}, 'name': 'recognized as'}, {'startNode': {'name': 'ives', 'label': 'Person'}, 'endNode': {'name': 'modernism', 'label': 'Movement'}, 'name': 'included as'}, {'startNode': {'name': 'ives', 'label': 'Person'}, 'endNode': {'name': 'tonality', 'label': 'Concept'}, 'name': 'challenged'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Jazz Fusion', 'label': 'Musical Genre'}, {'name': 'Jazz', 'label': 'Musical Genre'}, {'name': 'Rock', 'label': 'Musical Genre'}, {'name': 'Genre Fusion', 'label': 'Process'}, {'name': 'Late 1960s', 'label': 'Time Period'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'jazz', 'label': 'Musical_Genre'}, 'endNode': {'name': 'rock', 'label': 'Musical_Genre'}, 'name': 'combined_with'}, {'startNode': {'name': 'jazz', 'label': 'Musical_Genre'}, 'endNode': {'name': 'jazz fusion', 'label': 'Musical_Genre'}, 'name': 'evolved_into'}, {'startNode': {'name': 'rock', 'label': 'Musical_Genre'}, 'endNode': {'name': 'jazz fusion', 'label': 'Musical_Genre'}, 'name': 'evolved_into'}, {'startNode': {'name': 'genre fusion', 'label': 'Process'}, 'endNode': {'name': 'jazz fusion', 'label': 'Musical_Genre'}, 'name': 'resulted_in'}, {'startNode': {'name': 'late 1960s', 'label': 'Time_Period'}, 'endNode': {'name': 'jazz fusion', 'label': 'Musical_Genre'}, 'name': 'emerged_in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'label': 'Musical Form', 'name': 'Bebop Jazz'}, {'label': 'Technique', 'name': 'Altered Chords'}, {'label': 'Technique', 'name': 'Extended Chords'}, {'label': 'Time Period', 'name': '1940s'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'bebop jazz', 'label': 'Musical_Form'}, 'endNode': {'name': 'altered chords', 'label': 'Technique'}, 'name': 'uses'}, {'startNode': {'name': 'bebop jazz', 'label': 'Musical_Form'}, 'endNode': {'name': 'extended chords', 'label': 'Technique'}, 'name': 'features'}, {'startNode': {'name': 'bebop jazz', 'label': 'Musical_Form'}, 'endNode': {'name': '1940s', 'label': 'Time_Period'}, 'name': 'emerged in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Ralph Vaughan Williams', 'label': 'Person'}, {'name': 'Aaron Copland', 'label': 'Person'}, {'name': 'Carlos Chávez', 'label': 'Person'}, {'name': 'Heitor Villa-Lobos', 'label': 'Person'}, {'name': 'Folk themes', 'label': 'Technique'}, {'name': 'Compositions', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'ralph vaughan williams', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'used in'}, {'startNode': {'name': 'aaron copland', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'incorporated in'}, {'startNode': {'name': 'carlos chávez', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'utilized in'}, {'startNode': {'name': 'heitor villa lobos', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'included in'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=compositions, label=Process, properties=embeddings=array([ 0.01283477, -0.02478496, -0.01665724, ..., -0.0089686 ,
#         0.00614382,  0.0101562 ]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=aaron copland, label=Person, properties=embeddings=array([-6.37453049e-05, -1.28144383e-02, -1.03650261e-02, ...,
#         1.00888893e-03,  1.44823492e-03, -6.72440843e-03])), Entity(name=compositions, label=Process, properties=embeddings=array([ 0.01283477, -0.02478496, -0.01665724, ..., -0.0089686 ,
#         0.00614382,  0.0101562 ])), Entity(name=folk themes, label=Technique, properties=embeddings=array([-0.00710905, -0.01076599, -0.02328608, ..., -0.0137211 ,
#         0.01639313,  0.0049724 ])), Entity(name=heitor villa lobos, label=Person, properties=embeddings=array([-0.01002476,  0.02031854, -0.01033824, ...,  0.01109395,
#        -0.0023876 ,  0.00107583])), Entity(name=ralph vaughan williams, label=Person, properties=embeddings=array([ 9.39537771e-03, -2.11426895e-03, -7.27943210e-03, ...,
#        -5.58150590e-05, -8.03551637e-04,  1.93494447e-03])), Entity(name=carlos chávez, label=Person, properties=embeddings=array([-0.01218373,  0.02372791, -0.01214924, ...,  0.00711859,
#         0.00176056, -0.02643182]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'ralph vaughan williams', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'incorporated'}, {'startNode': {'name': 'aaron copland', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'incorporated'}, {'startNode': {'name': 'carlos chávez', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'utilized'}, {'startNode': {'name': 'heitor villa lobos', 'label': 'Person'}, 'endNode': {'name': 'folk themes', 'label': 'Technique'}, 'name': 'included'}, {'startNode': {'name': 'ralph vaughan williams', 'label': 'Person'}, 'endNode': {'name': 'compositions', 'label': 'Process'}, 'name': 'created'}, {'startNode': {'name': 'aaron copland', 'label': 'Person'}, 'endNode': {'name': 'compositions', 'label': 'Process'}, 'name': 'created'}, {'startNode': {'name': 'carlos chávez', 'label': 'Person'}, 'endNode': {'name': 'compositions', 'label': 'Process'}, 'name': 'created'}, {'startNode': {'name': 'heitor villa lobos', 'label': 'Person'}, 'endNode': {'name': 'compositions', 'label': 'Process'}, 'name': 'created'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [incorporated] --merged --> [incorporated_in]
# [INFO] Wohoo! Relation was matched --- [incorporated] --merged --> [incorporated_in]
# [INFO] Wohoo! Relation was matched --- [utilized] --merged --> [utilized_in]
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Ravel', 'label': 'Person'}, {'name': 'Milhaud', 'label': 'Person'}, {'name': 'Gershwin', 'label': 'Person'}, {'name': 'Classical Music', 'label': 'Music Genre'}, {'name': 'Jazz', 'label': 'Music Genre'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'ravel', 'label': 'Person'}, 'endNode': {'name': 'jazz', 'label': 'Music_Genre'}, 'name': 'combined with'}, {'startNode': {'name': 'milhaud', 'label': 'Person'}, 'endNode': {'name': 'jazz', 'label': 'Music_Genre'}, 'name': 'combined with'}, {'startNode': {'name': 'gershwin', 'label': 'Person'}, 'endNode': {'name': 'jazz', 'label': 'Music_Genre'}, 'name': 'combined with'}, {'startNode': {'name': 'ravel', 'label': 'Person'}, 'endNode': {'name': 'classical music', 'label': 'Music_Genre'}, 'name': 'combined with'}, {'startNode': {'name': 'milhaud', 'label': 'Person'}, 'endNode': {'name': 'classical music', 'label': 'Music_Genre'}, 'name': 'combined with'}, {'startNode': {'name': 'gershwin', 'label': 'Person'}, 'endNode': {'name': 'classical music', 'label': 'Music_Genre'}, 'name': 'combined with'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Contemporary classical music', 'label': 'Music Genre'}, {'name': 'Modernist music', 'label': 'Music Style'}, {'name': 'Postmodern music', 'label': 'Music Style'}, {'name': 'Neoromantic music', 'label': 'Music Style'}, {'name': 'Pluralist music', 'label': 'Music Style'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'modernist music', 'label': 'Music_Style'}, 'endNode': {'name': 'contemporary classical music', 'label': 'Music_Genre'}, 'name': 'included in'}, {'startNode': {'name': 'postmodern music', 'label': 'Music_Style'}, 'endNode': {'name': 'contemporary classical music', 'label': 'Music_Genre'}, 'name': 'included in'}, {'startNode': {'name': 'neoromantic music', 'label': 'Music_Style'}, 'endNode': {'name': 'contemporary classical music', 'label': 'Music_Genre'}, 'name': 'included in'}, {'startNode': {'name': 'pluralist music', 'label': 'Music_Style'}, 'endNode': {'name': 'contemporary classical music', 'label': 'Music_Genre'}, 'name': 'included in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Country music', 'label': 'Musical Form'}, {'name': 'Country and Western music', 'label': 'Musical Form'}, {'name': 'Southern United States', 'label': 'Region'}, {'name': 'Traditional folk music', 'label': 'Music Genre'}, {'name': 'Spirituals', 'label': 'Music Genre'}, {'name': 'Blues', 'label': 'Music Genre'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'country music', 'label': 'Musical_Form'}, 'endNode': {'name': 'country and western music', 'label': 'Musical_Form'}, 'name': 'was once called'}, {'startNode': {'name': 'country music', 'label': 'Musical_Form'}, 'endNode': {'name': 'southern united states', 'label': 'Region'}, 'name': 'developed in'}, {'startNode': {'name': 'country music', 'label': 'Musical_Form'}, 'endNode': {'name': 'traditional folk music', 'label': 'Music_Genre'}, 'name': 'has roots in'}, {'startNode': {'name': 'country music', 'label': 'Musical_Form'}, 'endNode': {'name': 'spirituals', 'label': 'Music_Genre'}, 'name': 'has roots in'}, {'startNode': {'name': 'country music', 'label': 'Musical_Form'}, 'endNode': {'name': 'blues', 'label': 'Music_Genre'}, 'name': 'has roots in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Disco', 'label': 'Music Style'}, {'name': 'Funk', 'label': 'Music Genre'}, {'name': 'Salsa', 'label': 'Music Genre'}, {'name': 'Soul', 'label': 'Music Genre'}, {'name': '1970s', 'label': 'Time Period'}, {'name': 'Gay Audience', 'label': 'Audience'}, {'name': 'African-American Audience', 'label': 'Audience'}, {'name': 'U.S. Cities', 'label': 'Location'}, {'name': 'Discothèque', 'label': 'French Word'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': '1970s', 'label': 'Time_Period'}, 'name': 'began_in'}, {'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': 'funk', 'label': 'Music_Genre'}, 'name': 'originates_from'}, {'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': 'salsa', 'label': 'Music_Genre'}, 'name': 'originates_from'}, {'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': 'soul', 'label': 'Music_Genre'}, 'name': 'originates_from'}, {'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': 'gay audience', 'label': 'Audience'}, 'name': 'popular_with'}, {'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': 'african american audience', 'label': 'Audience'}, 'name': 'popular_with'}, {'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': 'u.s. cities', 'label': 'Location'}, 'name': 'popular_in'}, {'startNode': {'name': 'disco', 'label': 'Music_Style'}, 'endNode': {'name': 'discothèque', 'label': 'French_Word'}, 'name': 'name_derived_from'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Music Variety', 'label': 'Concept'}, {'name': '20th Century', 'label': 'Time Period'}, {'name': 'Music Diversity', 'label': 'Concept'}, {'name': 'Music Range Expansion', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': '20th century', 'label': 'Time_Period'}, 'endNode': {'name': 'music variety', 'label': 'Concept'}, 'name': 'saw growth in'}, {'startNode': {'name': '20th century', 'label': 'Time_Period'}, 'endNode': {'name': 'music diversity', 'label': 'Concept'}, 'name': 'saw increase in'}, {'startNode': {'name': '20th century', 'label': 'Time_Period'}, 'endNode': {'name': 'music range expansion', 'label': 'Process'}, 'name': 'experienced'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Edgard Varèse', 'label': 'Person'}, {'name': 'Karlheinz Stockhausen', 'label': 'Person'}, {'name': 'Milton Babbitt', 'label': 'Person'}, {'name': 'Pierre Boulez', 'label': 'Person'}, {'name': 'Luigi Nono', 'label': 'Person'}, {'name': 'Herbert Brün', 'label': 'Person'}, {'name': 'Iannis Xenakis', 'label': 'Person'}, {'name': 'Electronic Music', 'label': 'Technique'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'Edgard Varèse', 'label': 'Person'}, 'endNode': {'name': 'electronic music', 'label': 'Technique'}, 'name': 'embraced'}, {'startNode': {'name': 'Karlheinz Stockhausen', 'label': 'Person'}, 'endNode': {'name': 'electronic music', 'label': 'Technique'}, 'name': 'embraced'}, {'startNode': {'name': 'Milton Babbitt', 'label': 'Person'}, 'endNode': {'name': 'electronic music', 'label': 'Technique'}, 'name': 'embraced'}, {'startNode': {'name': 'Pierre Boulez', 'label': 'Person'}, 'endNode': {'name': 'electronic music', 'label': 'Technique'}, 'name': 'embraced'}, {'startNode': {'name': 'Luigi Nono', 'label': 'Person'}, 'endNode': {'name': 'electronic music', 'label': 'Technique'}, 'name': 'embraced'}, {'startNode': {'name': 'Herbert Brün', 'label': 'Person'}, 'endNode': {'name': 'electronic music', 'label': 'Technique'}, 'name': 'embraced'}, {'startNode': {'name': 'Iannis Xenakis', 'label': 'Person'}, 'endNode': {'name': 'electronic music', 'label': 'Technique'}, 'name': 'embraced'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Jet Flights', 'label': 'Process'}, {'name': 'Faster Travel', 'label': 'Process'}, {'name': 'Musicians', 'label': 'Person'}, {'name': 'Fans', 'label': 'Person'}, {'name': 'Musical Styles', 'label': 'Concept'}, {'name': 'Spread of Musical Styles', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'jet flights', 'label': 'Process'}, 'endNode': {'name': 'faster travel', 'label': 'Process'}, 'name': 'enable'}, {'startNode': {'name': 'faster travel', 'label': 'Process'}, 'endNode': {'name': 'musicians', 'label': 'Person'}, 'name': 'benefit'}, {'startNode': {'name': 'faster travel', 'label': 'Process'}, 'endNode': {'name': 'fans', 'label': 'Person'}, 'name': 'benefit'}, {'startNode': {'name': 'faster travel', 'label': 'Process'}, 'endNode': {'name': 'spread of musical styles', 'label': 'Process'}, 'name': 'facilitate'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=musical styles, label=Concept, properties=embeddings=array([-0.00352134,  0.0013954 , -0.02964254, ...,  0.00117912,
#        -0.00290935,  0.00633138]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'musical styles', 'label': 'Concept'}, 'endNode': {'name': 'wider travel', 'label': 'Concept'}, 'name': 'increased with'}]}
# [INFO] Verification of invented entities
# [INFO][INVENTED ENTITIES] Aie; the entities label='Concept' name='wider travel' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=musicians, label=Person, properties=embeddings=array([ 1.18164625e-02,  3.85720121e-03, -2.09113088e-02, ...,
#         1.35521015e-03,  8.98065045e-05, -1.92479722e-02])), Entity(name=faster travel, label=Process, properties=embeddings=array([-0.00943439, -0.00337889, -0.00214155, ...,  0.00379248,
#        -0.00039305, -0.00749851])), Entity(name=spread of musical styles, label=Process, properties=embeddings=array([ 0.00242687, -0.00407603, -0.01588323, ...,  0.00729283,
#         0.00326475,  0.00643201])), Entity(name=fans, label=Person, properties=embeddings=array([-0.00495601,  0.0162881 , -0.01873751, ...,  0.00932677,
#        -0.00343437, -0.01844313])), Entity(name=jet flights, label=Process, properties=embeddings=array([-0.0104434 , -0.03095246, -0.0059186 , ...,  0.01412479,
#        -0.00177879, -0.01323799]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'musicians', 'label': 'Person'}, 'endNode': {'name': 'faster travel', 'label': 'Process'}, 'name': 'enabled by'}, {'startNode': {'name': 'faster travel', 'label': 'Process'}, 'endNode': {'name': 'jet flights', 'label': 'Process'}, 'name': 'facilitated by'}, {'startNode': {'name': 'musicians', 'label': 'Person'}, 'endNode': {'name': 'spread of musical styles', 'label': 'Process'}, 'name': 'contributes to'}, {'startNode': {'name': 'fans', 'label': 'Person'}, 'endNode': {'name': 'faster travel', 'label': 'Process'}, 'name': 'benefits from'}, {'startNode': {'name': 'spread of musical styles', 'label': 'Process'}, 'endNode': {'name': 'faster travel', 'label': 'Process'}, 'name': 'enhanced by'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-3] Aie; there are some isolated entities without relations [Entity(name=musical styles, label=Concept, properties=embeddings=array([-0.00352134,  0.0013954 , -0.02964254, ...,  0.00117912,
#        -0.00290935,  0.00633138]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'musical styles', 'label': 'Concept'}, 'endNode': {'name': 'musical styles', 'label': 'Concept'}, 'name': 'spread with wider travel'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Folk Music', 'label': 'Music Genre'}, {'name': 'Community', 'label': 'Group'}, {'name': 'Oral Tradition', 'label': 'Transmission Method'}, {'name': 'Amateurs', 'label': 'Performer Type'}, {'name': 'Professionals', 'label': 'Performer Type'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'endNode': {'name': 'community', 'label': 'Group'}, 'name': 'shared by'}, {'startNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'endNode': {'name': 'oral tradition', 'label': 'Transmission_Method'}, 'name': 'passed down through'}, {'startNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'endNode': {'name': 'professionals', 'label': 'Performer_Type'}, 'name': 'not performed by'}, {'startNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'endNode': {'name': 'amateurs', 'label': 'Performer_Type'}, 'name': 'possibly excluded from performing'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Folk Music', 'label': 'Music Genre'}, {'name': 'Johann Gottfried Herder', 'label': 'Person'}, {'name': 'Merrie England movement', 'label': 'Cultural Movement'}, {'name': 'Irish Gaelic Revival', 'label': 'Cultural Revival'}, {'name': 'Scottish Gaelic Revival', 'label': 'Cultural Revival'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'johann gottfried herder', 'label': 'Person'}, 'endNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'name': 'defined'}, {'startNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'endNode': {'name': 'merrie england movement', 'label': 'Cultural_Movement'}, 'name': 'associated_with'}, {'startNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'endNode': {'name': 'irish gaelic revival', 'label': 'Cultural_Revival'}, 'name': 'reflected_in'}, {'startNode': {'name': 'folk music', 'label': 'Music_Genre'}, 'endNode': {'name': 'scottish gaelic revival', 'label': 'Cultural_Revival'}, 'name': 'reflected_in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Instrumental Music', 'label': 'Category'}, {'name': 'Singing', 'label': 'Technique'}, {'name': 'Mechanical Technologies', 'label': 'Technique'}, {'name': 'Bow', 'label': 'Tool'}, {'name': 'String', 'label': 'Component'}, {'name': 'Hollow Instrument', 'label': 'Instrument'}, {'name': 'Plucking', 'label': 'Technique'}, {'name': 'Gut', 'label': 'Material'}, {'name': 'Metal', 'label': 'Material'}, {'name': 'String Instruments', 'label': 'Category'}, {'name': 'Woodwinds', 'label': 'Category'}, {'name': 'Brass', 'label': 'Category'}, {'name': 'Percussion Instruments', 'label': 'Category'}, {'name': 'Vibrating Air', 'label': 'Process'}, {'name': 'Rhythmic Sounds', 'label': 'Output'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'instrumental music', 'label': 'Category'}, 'endNode': {'name': 'singing', 'label': 'Technique'}, 'name': 'created by'}, {'startNode': {'name': 'instrumental music', 'label': 'Category'}, 'endNode': {'name': 'mechanical technologies', 'label': 'Technique'}, 'name': 'created by'}, {'startNode': {'name': 'bow', 'label': 'Tool'}, 'endNode': {'name': 'string', 'label': 'Component'}, 'name': 'drawn across'}, {'startNode': {'name': 'string', 'label': 'Component'}, 'endNode': {'name': 'hollow instrument', 'label': 'Instrument'}, 'name': 'part of'}, {'startNode': {'name': 'string instruments', 'label': 'Category'}, 'endNode': {'name': 'string', 'label': 'Component'}, 'name': 'use'}, {'startNode': {'name': 'string', 'label': 'Component'}, 'endNode': {'name': 'gut', 'label': 'Material'}, 'name': 'made of'}, {'startNode': {'name': 'string', 'label': 'Component'}, 'endNode': {'name': 'metal', 'label': 'Material'}, 'name': 'made of'}, {'startNode': {'name': 'woodwinds', 'label': 'Category'}, 'endNode': {'name': 'vibrating air', 'label': 'Process'}, 'name': 'constrict'}, {'startNode': {'name': 'brass', 'label': 'Category'}, 'endNode': {'name': 'vibrating air', 'label': 'Process'}, 'name': 'constrict'}, {'startNode': {'name': 'percussion instruments', 'label': 'Category'}, 'endNode': {'name': 'rhythmic sounds', 'label': 'Output'}, 'name': 'produce'}]}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=plucking, label=Technique, properties=embeddings=array([ 0.01235601, -0.00823593, -0.00790459, ...,  0.00290322,
#        -0.01076746, -0.00210012]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=mechanical technologies, label=Technique, properties=embeddings=array([ 0.01055826, -0.00196097, -0.02583371, ..., -0.00414044,
#        -0.02616756,  0.00634253])), Entity(name=metal, label=Material, properties=embeddings=array([-0.01966738,  0.00593809, -0.01078487, ..., -0.00552464,
#        -0.01432614,  0.01393794])), Entity(name=instrumental music, label=Category, properties=embeddings=array([-0.00285738, -0.00119049, -0.02543791, ..., -0.00679472,
#        -0.01459995,  0.00517548])), Entity(name=singing, label=Technique, properties=embeddings=array([ 0.0214773 ,  0.00295716, -0.01340289, ...,  0.00438497,
#        -0.00797745, -0.00156048])), Entity(name=plucking, label=Technique, properties=embeddings=array([ 0.01235601, -0.00823593, -0.00790459, ...,  0.00290322,
#        -0.01076746, -0.00210012])), Entity(name=woodwinds, label=Category, properties=embeddings=array([-0.0030189 ,  0.01982053, -0.02208725, ..., -0.00681173,
#        -0.00684358, -0.00083224])), Entity(name=percussion instruments, label=Category, properties=embeddings=array([ 0.00513615,  0.01263915, -0.02420482, ..., -0.00903751,
#        -0.01027847, -0.0030776 ])), Entity(name=vibrating air, label=Process, properties=embeddings=array([-0.00121139, -0.02353309,  0.00318075, ...,  0.00324125,
#        -0.0017586 ,  0.00242835])), Entity(name=string, label=Component, properties=embeddings=array([ 0.01180683, -0.00297445, -0.00987175, ..., -0.00526935,
#        -0.00068214, -0.01062862])), Entity(name=string instruments, label=Category, properties=embeddings=array([ 0.00879097,  0.01220104, -0.020199  , ..., -0.01377254,
#        -0.00472705, -0.00787524])), Entity(name=gut, label=Material, properties=embeddings=array([ 0.00675382,  0.0254877 ,  0.0065928 , ..., -0.01840578,
#        -0.02528628,  0.00579478])), Entity(name=bow, label=Tool, properties=embeddings=array([-0.01661655, -0.02207344, -0.01738921, ...,  0.00094416,
#        -0.01843312, -0.00019846])), Entity(name=hollow instrument, label=Instrument, properties=embeddings=array([-0.00413142, -0.02809683, -0.01124121, ..., -0.0065282 ,
#        -0.02452166, -0.00936391])), Entity(name=brass, label=Category, properties=embeddings=array([ 0.00797136,  0.0122312 , -0.01852672, ..., -0.01851411,
#        -0.00690968,  0.01284858])), Entity(name=rhythmic sounds, label=Output, properties=embeddings=array([ 0.00755179,  0.00176064, -0.00906091, ...,  0.00325983,
#         0.00391741, -0.01143663]))]. Solving them ...
# {'relationships': [{'startNode': {'name': 'mechanical technologies', 'label': 'Technique'}, 'endNode': {'name': 'instrumental music', 'label': 'Category'}, 'name': 'used in'}, {'startNode': {'name': 'metal', 'label': 'Material'}, 'endNode': {'name': 'string', 'label': 'Component'}, 'name': 'material of'}, {'startNode': {'name': 'singing', 'label': 'Technique'}, 'endNode': {'name': 'instrumental music', 'label': 'Category'}, 'name': 'alternative to'}, {'startNode': {'name': 'plucking', 'label': 'Technique'}, 'endNode': {'name': 'string instruments', 'label': 'Category'}, 'name': 'technique for'}, {'startNode': {'name': 'woodwinds', 'label': 'Category'}, 'endNode': {'name': 'vibrating air', 'label': 'Process'}, 'name': 'produces'}, {'startNode': {'name': 'percussion instruments', 'label': 'Category'}, 'endNode': {'name': 'rhythmic sounds', 'label': 'Output'}, 'name': 'produces'}, {'startNode': {'name': 'string', 'label': 'Component'}, 'endNode': {'name': 'string instruments', 'label': 'Category'}, 'name': 'component of'}, {'startNode': {'name': 'gut', 'label': 'Material'}, 'endNode': {'name': 'string', 'label': 'Component'}, 'name': 'material of'}, {'startNode': {'name': 'bow', 'label': 'Tool'}, 'endNode': {'name': 'string instruments', 'label': 'Category'}, 'name': 'used with'}, {'startNode': {'name': 'hollow instrument', 'label': 'Instrument'}, 'endNode': {'name': 'string instruments', 'label': 'Category'}, 'name': 'type of'}, {'startNode': {'name': 'brass', 'label': 'Category'}, 'endNode': {'name': 'vibrating air', 'label': 'Process'}, 'name': 'produces'}]}
# [INFO] Verification of invented entities
# [INFO] Wohoo! Relation was matched --- [material_of] --merged --> [made_of]
# [INFO] Wohoo! Relation was matched --- [material_of] --merged --> [made_of]
# [INFO] Wohoo! Relation was matched --- [produces] --merged --> [produce]
# [INFO] Wohoo! Relation was matched --- [produces] --merged --> [produce]
# [INFO] Wohoo! Relation was matched --- [produces] --merged --> [produce]
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Chromatic Language', 'label': 'Technique'}, {'name': 'Tonality', 'label': 'Technique'}, {'name': 'Atonal Music', 'label': 'Technique'}, {'name': 'Arnold Schoenberg', 'label': 'Person'}, {'name': 'Erwartung', 'label': 'Opera'}, {'name': 'Die glückliche Hand', 'label': 'Opera'}, {'name': 'Alban Berg', 'label': 'Person'}, {'name': 'Wozzeck', 'label': 'Opera'}]}
# [INFO] ------- Extracting Relations from the Document 1
# ...
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'live performances', 'label': 'Event_Type'}, 'endNode': {'name': 'affordability', 'label': 'Economic_Factor'}, 'name': 'affected by'}, {'startNode': {'name': 'classical music', 'label': 'Genre'}, 'endNode': {'name': 'regional availability', 'label': 'Geographical_Factor'}, 'name': 'limited by'}, {'startNode': {'name': 'classical music', 'label': 'Genre'}, 'endNode': {'name': 'symphonies', 'label': 'Performance_Type'}, 'name': 'includes'}, {'startNode': {'name': 'classical music', 'label': 'Genre'}, 'endNode': {'name': 'operas', 'label': 'Performance_Type'}, 'name': 'includes'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'String Section', 'label': 'Instrument Group'}, {'name': 'Woodwinds', 'label': 'Instrument Group'}, {'name': 'Brass Instruments', 'label': 'Instrument Group'}, {'name': 'Percussion Instruments', 'label': 'Instrument Group'}, {'name': 'Piano', 'label': 'Instrument'}, {'name': 'Celeste', 'label': 'Instrument'}, {'name': 'Harp', 'label': 'Instrument'}, {'name': 'Electric Guitar', 'label': 'Instrument'}, {'name': 'Electric Bass', 'label': 'Instrument'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'string section', 'label': 'Instrument_Group'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'part of'}, {'startNode': {'name': 'woodwinds', 'label': 'Instrument_Group'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'part of'}, {'startNode': {'name': 'brass instruments', 'label': 'Instrument_Group'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'part of'}, {'startNode': {'name': 'percussion instruments', 'label': 'Instrument_Group'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'part of'}, {'startNode': {'name': 'piano', 'label': 'Instrument'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'part of'}, {'startNode': {'name': 'celeste', 'label': 'Instrument'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'part of'}, {'startNode': {'name': 'harp', 'label': 'Instrument'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'sometimes used in'}, {'startNode': {'name': 'electric guitar', 'label': 'Instrument'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'occasionally used in'}, {'startNode': {'name': 'electric bass', 'label': 'Instrument'}, 'endNode': {'name': 'twentieth-century orchestras', 'label': 'Context'}, 'name': 'sometimes included in'}]}
# [INFO] Verification of invented entities
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO][INVENTED ENTITIES] Aie; the entities label='Context' name='twentieth century orchestras' properties=EntityProperties(embeddings=None) is invented. Solving it ...
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Sound Recording Technology', 'label': 'Technology'}, {'name': 'Popular Music', 'label': 'Music Genre'}, {'name': 'Mass Marketing', 'label': 'Process'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'sound recording technology', 'label': 'Technology'}, 'endNode': {'name': 'popular music', 'label': 'Music_Genre'}, 'name': 'linked to'}, {'startNode': {'name': 'sound recording technology', 'label': 'Technology'}, 'endNode': {'name': 'popular music', 'label': 'Music_Genre'}, 'name': 'played a key role in the creation of'}, {'startNode': {'name': 'sound recording technology', 'label': 'Technology'}, 'endNode': {'name': 'mass marketing', 'label': 'Process'}, 'name': 'enabled'}, {'startNode': {'name': 'mass marketing', 'label': 'Process'}, 'endNode': {'name': 'popular music', 'label': 'Music_Genre'}, 'name': 'of'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Gramophone Records', 'label': 'Product'}, {'name': 'Radio Broadcasts', 'label': 'Technology'}, {'name': 'Music Recordings', 'label': 'Product'}, {'name': 'Live Music Broadcasts', 'label': 'Service'}, {'name': 'Global Music Accessibility', 'label': 'Phenomenon'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'gramophone records', 'label': 'Product'}, 'endNode': {'name': 'global music accessibility', 'label': 'Phenomenon'}, 'name': 'contributed to'}, {'startNode': {'name': 'radio broadcasts', 'label': 'Technology'}, 'endNode': {'name': 'global music accessibility', 'label': 'Phenomenon'}, 'name': 'enabled'}, {'startNode': {'name': 'live music broadcasts', 'label': 'Service'}, 'endNode': {'name': 'global music accessibility', 'label': 'Phenomenon'}, 'name': 'enhanced'}, {'startNode': {'name': 'music recordings', 'label': 'Product'}, 'endNode': {'name': 'global music accessibility', 'label': 'Phenomenon'}, 'name': 'facilitated'}, {'startNode': {'name': 'radio broadcasts', 'label': 'Technology'}, 'endNode': {'name': 'live music broadcasts', 'label': 'Service'}, 'name': 'provided'}, {'startNode': {'name': 'gramophone records', 'label': 'Product'}, 'endNode': {'name': 'music recordings', 'label': 'Product'}, 'name': 'included'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Alexander Scriabin', 'label': 'Person'}, {'name': 'Claude Debussy', 'label': 'Person'}, {'name': 'Gustav Mahler', 'label': 'Person'}, {'name': 'Richard Strauss', 'label': 'Person'}, {'name': 'Modernism', 'label': 'Movement'}, {'name': 'Post-Wagnerian', 'label': 'Movement'}, {'name': 'Musical Form', 'label': 'Concept'}, {'name': 'Tonality', 'label': 'Concept'}, {'name': 'Orchestration Techniques', 'label': 'Technique'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'Alexander Scriabin', 'label': 'Person'}, 'endNode': {'name': 'Modernism', 'label': 'Movement'}, 'name': 'was a key figure in'}, {'startNode': {'name': 'Claude Debussy', 'label': 'Person'}, 'endNode': {'name': 'Modernism', 'label': 'Movement'}, 'name': 'was an important figure in'}, {'startNode': {'name': 'Gustav Mahler', 'label': 'Person'}, 'endNode': {'name': 'Post-Wagnerian', 'label': 'Movement'}, 'name': 'was included in'}, {'startNode': {'name': 'Richard Strauss', 'label': 'Person'}, 'endNode': {'name': 'Modernism', 'label': 'Movement'}, 'name': 'was known for'}, {'startNode': {'name': 'Alexander Scriabin', 'label': 'Person'}, 'endNode': {'name': 'Musical Form', 'label': 'Concept'}, 'name': 'experimented with'}, {'startNode': {'name': 'Claude Debussy', 'label': 'Person'}, 'endNode': {'name': 'Musical Form', 'label': 'Concept'}, 'name': 'experimented with'}, {'startNode': {'name': 'Gustav Mahler', 'label': 'Person'}, 'endNode': {'name': 'Musical Form', 'label': 'Concept'}, 'name': 'experimented with'}, {'startNode': {'name': 'Richard Strauss', 'label': 'Person'}, 'endNode': {'name': 'Musical Form', 'label': 'Concept'}, 'name': 'experimented with'}, {'startNode': {'name': 'Alexander Scriabin', 'label': 'Person'}, 'endNode': {'name': 'Tonality', 'label': 'Concept'}, 'name': 'explored new approaches to'}, {'startNode': {'name': 'Claude Debussy', 'label': 'Person'}, 'endNode': {'name': 'Tonality', 'label': 'Concept'}, 'name': 'explored new approaches to'}, {'startNode': {'name': 'Gustav Mahler', 'label': 'Person'}, 'endNode': {'name': 'Tonality', 'label': 'Concept'}, 'name': 'explored new approaches to'}, {'startNode': {'name': 'Richard Strauss', 'label': 'Person'}, 'endNode': {'name': 'Tonality', 'label': 'Concept'}, 'name': 'explored new approaches to'}, {'startNode': {'name': 'Alexander Scriabin', 'label': 'Person'}, 'endNode': {'name': 'Orchestration Techniques', 'label': 'Technique'}, 'name': 'innovated in'}, {'startNode': {'name': 'Claude Debussy', 'label': 'Person'}, 'endNode': {'name': 'Orchestration Techniques', 'label': 'Technique'}, 'name': 'innovated in'}, {'startNode': {'name': 'Gustav Mahler', 'label': 'Person'}, 'endNode': {'name': 'Orchestration Techniques', 'label': 'Technique'}, 'name': 'innovated in'}, {'startNode': {'name': 'Richard Strauss', 'label': 'Person'}, 'endNode': {'name': 'Orchestration Techniques', 'label': 'Technique'}, 'name': 'innovated in'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Schoenberg', 'label': 'Person'}, {'name': 'Berg', 'label': 'Person'}, {'name': 'twelve-tone technique', 'label': 'Technique'}, {'name': 'Moses und Aron', 'label': 'Opera'}, {'name': 'Lulu', 'label': 'Opera'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'schoenberg', 'label': 'Person'}, 'endNode': {'name': 'moses und aron', 'label': 'Opera'}, 'name': 'composed'}, {'startNode': {'name': 'schoenberg', 'label': 'Person'}, 'endNode': {'name': 'twelve tone technique', 'label': 'Technique'}, 'name': 'used'}, {'startNode': {'name': 'moses und aron', 'label': 'Opera'}, 'endNode': {'name': 'twelve tone technique', 'label': 'Technique'}, 'name': 'employs'}, {'startNode': {'name': 'berg', 'label': 'Person'}, 'endNode': {'name': 'lulu', 'label': 'Opera'}, 'name': 'composed'}, {'startNode': {'name': 'berg', 'label': 'Person'}, 'endNode': {'name': 'twelve tone technique', 'label': 'Technique'}, 'name': 'used'}, {'startNode': {'name': 'lulu', 'label': 'Opera'}, 'endNode': {'name': 'twelve tone technique', 'label': 'Technique'}, 'name': 'employs'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'The Grascals', 'label': 'Band'}, {'name': 'Mountain Heart', 'label': 'Band'}, {'name': 'Bluegrass', 'label': 'Subgenre'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'the grascals', 'label': 'Band'}, 'endNode': {'name': 'bluegrass', 'label': 'Subgenre'}, 'name': 'belongs to'}, {'startNode': {'name': 'mountain heart', 'label': 'Band'}, 'endNode': {'name': 'bluegrass', 'label': 'Subgenre'}, 'name': 'belongs to'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Electric and Electronic Technology', 'label': 'Technology'}, {'name': 'Sound Recording', 'label': 'Process'}, {'name': 'Art Music Production', 'label': 'Application'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'electric and electronic technology', 'label': 'Technology'}, 'endNode': {'name': 'sound recording', 'label': 'Process'}, 'name': 'used for'}, {'startNode': {'name': 'sound recording', 'label': 'Process'}, 'endNode': {'name': 'art music production', 'label': 'Application'}, 'name': 'applied to'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Phonograph', 'label': 'Invention'}, {'name': 'Phonograph players', 'label': 'Technology'}, {'name': '1877', 'label': 'Year'}, {'name': 'Mid-1890s', 'label': 'Time Period'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'phonograph', 'label': 'Invention'}, 'endNode': {'name': '1877', 'label': 'Year'}, 'name': 'was invented in'}, {'startNode': {'name': 'phonograph players', 'label': 'Technology'}, 'endNode': {'name': 'mid 1890s', 'label': 'Time_Period'}, 'name': 'were mass-marketed in'}, {'startNode': {'name': 'phonograph players', 'label': 'Technology'}, 'endNode': {'name': 'phonograph', 'label': 'Invention'}, 'name': 'are based on'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Playing Music at Home', 'label': 'Process'}, {'name': 'Sheet Music', 'label': 'Data Structure'}, {'name': 'Singing', 'label': 'Skill'}, {'name': 'Playing an Instrument', 'label': 'Skill'}, {'name': 'Reading Music', 'label': 'Skill'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'playing music at home', 'label': 'Process'}, 'endNode': {'name': 'sheet music', 'label': 'Data_Structure'}, 'name': 'uses'}, {'startNode': {'name': 'playing music at home', 'label': 'Process'}, 'endNode': {'name': 'reading music', 'label': 'Skill'}, 'name': 'requires'}, {'startNode': {'name': 'playing music at home', 'label': 'Process'}, 'endNode': {'name': 'singing', 'label': 'Skill'}, 'name': 'requires'}, {'startNode': {'name': 'playing music at home', 'label': 'Process'}, 'endNode': {'name': 'playing an instrument', 'label': 'Skill'}, 'name': 'requires'}]}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Breakdowns', 'label': 'Music Technique'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-1] Aie; there are some isolated entities without relations [Entity(name=breakdowns, label=Music_Technique, properties=embeddings=array([ 0.00383226,  0.00413616, -0.01860799, ..., -0.01861803,
#         0.00177538, -0.00272942]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-2] Aie; there are some isolated entities without relations [Entity(name=breakdowns, label=Music_Technique, properties=embeddings=array([ 0.00383226,  0.00413616, -0.01860799, ..., -0.01861803,
#         0.00177538, -0.00272942]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO][ISOLATED ENTITIES][TRY-3] Aie; there are some isolated entities without relations [Entity(name=breakdowns, label=Music_Technique, properties=embeddings=array([ 0.00383226,  0.00413616, -0.01860799, ..., -0.01861803,
#         0.00177538, -0.00272942]))]. Solving them ...
# {'relationships': []}
# [INFO] Verification of invented entities
# [INFO] ------- Extracting Entities from the Document 1
# {'entities': [{'name': 'Cost', 'label': 'Concept'}, {'name': 'Lower Incomes', 'label': 'Demographic'}]}
# [INFO] ------- Extracting Relations from the Document 1
# {'relationships': [{'startNode': {'name': 'cost', 'label': 'Concept'}, 'endNode': {'name': 'lower incomes', 'label': 'Demographic'}, 'name': 'are unaffordable for'}]}
# [INFO] Verification of invented entities

# %%
grouped_music["Triplets_From_Original_Sentences"] = grouped_music["Combined_Sentences"].apply(lambda x: extract_triplets_from_original_sentences(x))

# %% [markdown]
# ## Save the two datasets
# ---

# %% [markdown]
# The samething applies for grouped_cs dataset

# %%
import pickle

with open("./grouped_music_.pkl", "wb") as file:
    pickle.dump(grouped_music, file)

# %%
grouped_music.to_excel("./grouped_music.xlsx", index=False)
