# %%
from langchain_ollama import ChatOllama, OllamaEmbeddings
from neo4j import GraphDatabase
from neo4j_graphrag.generation import GraphRAG
from neo4j_graphrag.retrievers import VectorRetriever
from neo4j_graphrag.indexes import create_vector_index
import logging
from langchain_community.graphs import Neo4jGraph

# llm = ChatGoogleGenerativeAI(
#     model="gemini-2.0-flash", 
#     google_api_key="AIzaSyDVhEJMmWWJCGzrDQWoE0ffYROeRQ4jcp0", 
#     temperature=0)

logging.basicConfig(level=logging.INFO)

NEO4J_URI = "neo4j+s://435eb4f0.databases.neo4j.io"
NEO4J_USERNAME = "neo4j"
NEO4J_PASSWORD = "nqL3At3rptFpfRrBhg5Y1-7k78oHqVaW42WKtqVRnJo"


# NEO4J_URI = "bolt://localhost:7687"
# NEO4J_USERNAME = "neo4j"
# NEO4J_PASSWORD = "fuli556600!"

OLLAMA_BASE_URL = "http://localhost:11434"  # Ollama 默认端口
OLLAMA_MODEL = "deepseek-r1:32b" # 你选择的ollama模型

llm = ChatOllama(
    model="deepseek-r1:32b",
    temperature=0,
)

embedder = OllamaEmbeddings(
    model="nomic-embed-text:latest",
)

# %%
graph = Neo4jGraph(
    url=NEO4J_URI,
    username=NEO4J_USERNAME,
    password=NEO4J_PASSWORD
)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:114, in NetworkUtil._dns_resolver(address, family)
#     113 try:
# --> 114     info = NetworkUtil.get_address_info(
#     115         address.host, address.port, family=family,
#     116         type=socket.SOCK_STREAM
#     117     )
#     118 except OSError:
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:102, in NetworkUtil.get_address_info(host, port, family, type, proto, flags)
#     100 @staticmethod
#     101 def get_address_info(host, port, *, family=0, type=0, proto=0, flags=0):
# --> 102     return socket.getaddrinfo(host, port, family, type, proto, flags)
#
# File ~/miniconda3/envs/kg/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 graph = Neo4jGraph(
#       2     url=NEO4J_URI,
#       3     username=NEO4J_USERNAME,
#       4     password=NEO4J_PASSWORD
#       5 )
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/langchain_core/_api/deprecation.py:214, in deprecated.<locals>.deprecate.<locals>.finalize.<locals>.warn_if_direct_instance(self, *args, **kwargs)
#     212     warned = True
#     213     emit_warning()
# --> 214 return wrapped(self, *args, **kwargs)
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/langchain_community/graphs/neo4j_graph.py:415, in Neo4jGraph.__init__(self, url, username, password, database, timeout, sanitize, refresh_schema, driver_config, enhanced_schema)
#     413 # Verify connection
#     414 try:
# --> 415     self._driver.verify_connectivity()
#     416 except neo4j.exceptions.ServiceUnavailable:
#     417     raise ValueError(
#     418         "Could not connect to Neo4j database. "
#     419         "Please ensure that the url is correct"
#     420     )
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/driver.py:1067, in Driver.verify_connectivity(self, **config)
#    1060     experimental_warn(
#    1061         "All configuration key-word arguments to "
#    1062         "verify_connectivity() are experimental. They might be "
#    1063         "changed or removed in any future version without prior "
#    1064         "notice."
#    1065     )
#    1066 session_config = self._read_session_config(config)
# -> 1067 self._get_server_info(session_config)
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/driver.py:1281, in Driver._get_server_info(self, session_config)
#    1279 def _get_server_info(self, session_config) -> ServerInfo:
#    1280     with self._session(session_config) as session:
# -> 1281         return session._get_server_info()
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/session.py:172, in Session._get_server_info(self)
#     170 def _get_server_info(self):
#     171     assert not self._connection
# --> 172     self._connect(READ_ACCESS, liveness_check_timeout=0)
#     173     server_info = self._connection.server_info
#     174     self._disconnect()
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/session.py:130, in Session._connect(self, access_mode, **acquire_kwargs)
#     128     access_mode = self._config.default_access_mode
#     129 try:
# --> 130     super()._connect(
#     131         access_mode, auth=self._config.auth, **acquire_kwargs
#     132     )
#     133 except asyncio.CancelledError:
#     134     self._handle_cancellation(message="_connect")
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/workspace.py:165, in Workspace._connect(self, access_mode, auth, **acquire_kwargs)
#     157     else:
#     158         # This is the first time we open a connection to a server in a
#     159         # cluster environment for this session without explicitly
#    (...)
#     162         # we shall use this database explicitly for all subsequent
#     163         # actions within this session.
#     164         log.debug("[#0000]  _: <WORKSPACE> resolve home database")
# --> 165         self._pool.update_routing_table(
#     166             database=self._config.database,
#     167             imp_user=self._config.impersonated_user,
#     168             bookmarks=self._get_bookmarks(),
#     169             auth=auth,
#     170             acquisition_timeout=acquisition_timeout,
#     171             database_callback=self._set_cached_database
#     172         )
#     173 acquire_kwargs_ = {
#     174     "access_mode": access_mode,
#     175     "timeout": acquisition_timeout,
#    (...)
#     179     "liveness_check_timeout": None,
#     180 }
#     181 acquire_kwargs_.update(acquire_kwargs)
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:774, in Neo4jPool.update_routing_table(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback)
#     769 prefer_initial_routing_address = \
#     770     self.routing_tables[database].initialized_without_writers
#     772 if prefer_initial_routing_address:
#     773     # TODO: Test this state
# --> 774     if self._update_routing_table_from(
#     775         self.address, database=database,
#     776         imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     777         acquisition_timeout=acquisition_timeout,
#     778         database_callback=database_callback
#     779     ):
#     780         # Why is only the first initial routing address used?
#     781         return
#     782 if self._update_routing_table_from(
#     783     *(existing_routers - {self.address}), database=database,
#     784     imp_user=imp_user, bookmarks=bookmarks, auth=auth,
#     785     acquisition_timeout=acquisition_timeout,
#     786     database_callback=database_callback
#     787 ):
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/io/_pool.py:717, in Neo4jPool._update_routing_table_from(self, database, imp_user, bookmarks, auth, acquisition_timeout, database_callback, *routers)
#     714     log.debug("[#0000]  _: <POOL> attempting to update routing "
#     715               "table from {}".format(", ".join(map(repr, routers))))
#     716 for router in routers:
# --> 717     for address in NetworkUtil.resolve_address(
#     718         router, resolver=self.pool_config.resolver
#     719     ):
#     720         new_routing_table = self.fetch_routing_table(
#     721             address=address, acquisition_timeout=acquisition_timeout,
#     722             database=database, imp_user=imp_user, bookmarks=bookmarks,
#     723             auth=auth
#     724         )
#     725         if new_routing_table is not None:
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:157, in NetworkUtil.resolve_address(address, family, resolver)
#     155             yield resolved_address
#     156 else:
# --> 157     for resolved_address in NetworkUtil._dns_resolver(
#     158         address, family=family
#     159     ):
#     160         log.debug("[#0000]  _: <RESOLVE> dns resolver out: %s",
#     161                   resolved_address)
#     162         yield resolved_address
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_async_compat/network/_util.py:119, in NetworkUtil._dns_resolver(address, family)
#     114     info = NetworkUtil.get_address_info(
#     115         address.host, address.port, family=family,
#     116         type=socket.SOCK_STREAM
#     117     )
#     118 except OSError:
# --> 119     raise ValueError("Cannot resolve address {}".format(address))
#     120 return _resolved_addresses_from_info(info, address._host_name)
#
# ValueError: Cannot resolve address 435eb4f0.databases.neo4j.io:7687

# %%
from langchain_core.exceptions import OutputParserException
from langchain.prompts import PromptTemplate
from langchain_core.output_parsers import JsonOutputParser
from itext2kg.utils.schemas import DiseaseArticle

def escape_curly_braces(text):
    return text.replace("{", "{{").replace("}", "}}")

with open("/home/mindrank/fuli/itext2kg/Data/AD_pubtabor/39912892.txt", "r") as f:
    text = f.readlines()
    title = text[0].strip().split('|')[-1]
    abstract = text[1].strip().split('|')[-1]
    title = escape_curly_braces(title)
    abstract = escape_curly_braces(abstract)
    context = f"Title: {title} Abstract: {abstract}"
query = """
# DIRECTIVES:
- As an experienced information extractor, your task is to extract biological entities from the provided bioinformatics context.
- Only extract entities that are explicitly mentioned in the context; do not generate or create any new terms.
- Extracted entities may include, but are not limited to, gene names, protein names, disease names, biological processes, pathways, molecular interactions, and other key bioinformatics terms.
- If an entity is not clearly mentioned in the context, leave it blank and do not infer or generate non-existent information.
- The output should only include the entities, excluding any non-entity content such as descriptive text or inferences.
"""

llm = ChatOllama(
        model="deepseek-r1:32b",  # 或你的自定义模型
        temperature=0,
        base_url=f"http://127.0.0.1:11434"  # 使用传入的端口
    )

parser = JsonOutputParser(pydantic_object=DiseaseArticle)

template = f"""
Context: {context}

Question: {query}
Format_instructions : {{format_instructions}}
Answer: """

prompt = PromptTemplate(
    template=template,
    input_variables=["query"],
    partial_variables={"format_instructions": parser.get_format_instructions()},
)

chain = prompt | llm | parser
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 25
#      15     context = f"Title: {title} Abstract: {abstract}"
#      16 query = """
#      17 # DIRECTIVES:
#      18 - As an experienced information extractor, your task is to extract biological entities from the provided bioinformatics context.
#    (...)     22 - The output should only include the entities, excluding any non-entity content such as descriptive text or inferences.
#      23 """
# ---> 25 llm = ChatOllama(
#      26         model="deepseek-r1:32b",  # 或你的自定义模型
#      27         temperature=0,
#      28         base_url=f"http://127.0.0.1:11434"  # 使用传入的端口
#      29     )
#      31 parser = JsonOutputParser(pydantic_object=DiseaseArticle)
#      33 template = f"""
#      34 Context: {context}
#      35
#      36 Question: {query}
#      37 Format_instructions : {{format_instructions}}
#      38 Answer: """
#
# NameError: name 'ChatOllama' is not defined

# %%
INDEX_NAME = "disease_embedding_index"

driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))

create_vector_index(
    driver, INDEX_NAME, 
    label="disease", 
    embedding_property="embeddings", 
    dimensions=768, 
    similarity_fn="euclidean")

retriever = VectorRetriever(
    driver,
    index_name=INDEX_NAME,
    embedder=embedder,
    return_properties=["name","unique_id"],
)

print(f"Using index: {retriever.index_name}")

#-------------------------搜索相似向量-------------------------
query_text = "delirium"

query_vector = embedder.embed_query(query_text)
response = retriever.search(query_vector=query_vector, top_k=10)

for result in response.items:
    print(result.content)
# Out:
# INFO:neo4j_graphrag.indexes:Creating vector index named 'disease_embedding_index'
# ---------------------------------------------------------------------------
# CypherSyntaxError                         Traceback (most recent call last)
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j_graphrag/indexes.py:117, in create_vector_index(driver, name, label, embedding_property, dimensions, similarity_fn, fail_if_exists, neo4j_database)
#     116     logger.info(f"Creating vector index named '{name}'")
# --> 117     driver.execute_query(
#     118         query,
#     119         {"name": name, "dimensions": dimensions, "similarity_fn": similarity_fn},
#     120         database_=neo4j_database,
#     121     )
#     122 except neo4j.exceptions.ClientError as e:
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/driver.py:959, in Driver.execute_query(self, query_, parameters_, routing_, database_, impersonated_user_, bookmark_manager_, auth_, result_transformer_, **kwargs)
#     958 with session._pipelined_begin:
# --> 959     return session._run_transaction(
#     960         access_mode, TelemetryAPI.DRIVER,
#     961         work, (query_str, parameters, result_transformer_), {}
#     962     )
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/session.py:554, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     553 try:
# --> 554     result = transaction_function(tx, *args, **kwargs)
#     555 except asyncio.CancelledError:
#     556     # if cancellation callback has not been called yet:
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/driver.py:1290, in _work(tx, query, parameters, transformer)
#    1284 def _work(
#    1285     tx: ManagedTransaction,
#    1286     query: te.LiteralString,
#    1287     parameters: t.Dict[str, t.Any],
#    1288     transformer: t.Callable[[Result], t.Union[_T]]
#    1289 ) -> _T:
# -> 1290     res = tx.run(query, parameters)
#    1291     return transformer(res)
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/transaction.py:172, in TransactionBase.run(self, query, parameters, **kwparameters)
#     171 parameters = dict(parameters or {}, **kwparameters)
# --> 172 result._tx_ready_run(query, parameters)
#     174 return result
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/result.py:171, in Result._tx_ready_run(self, query, parameters)
#     167 def _tx_ready_run(self, query, parameters):
#     168     # BEGIN+RUN does not carry any extra on the RUN message.
#     169     # BEGIN {extra}
#     170     # RUN "query" {parameters} {extra}
# --> 171     self._run(query, parameters, None, None, None, None, None, None)
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/result.py:221, in Result._run(self, query, parameters, db, imp_user, access_mode, bookmarks, notifications_min_severity, notifications_disabled_classifications)
#     220 self._connection.send_all()
# --> 221 self._attach()
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/work/result.py:409, in Result._attach(self)
#     408 while self._attached is False:
# --> 409     self._connection.fetch_message()
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:178, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     177 try:
# --> 178     func(*args, **kwargs)
#     179 except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/io/_bolt.py:860, in Bolt.fetch_message(self)
#     857 tag, fields = self.inbox.pop(
#     858     hydration_hooks=self.responses[0].hydration_hooks
#     859 )
# --> 860 res = self._process_message(tag, fields)
#     861 self.idle_since = monotonic()
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/io/_bolt4.py:368, in Bolt4x0._process_message(self, tag, fields)
#     367 try:
# --> 368     response.on_failure(summary_metadata or {})
#     369 except (ServiceUnavailable, DatabaseUnavailable):
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j/_sync/io/_common.py:245, in Response.on_failure(self, metadata)
#     244 Util.callback(handler)
# --> 245 raise Neo4jError.hydrate(**metadata)
#
# CypherSyntaxError: {code: Neo.ClientError.Statement.SyntaxError} {message: Invalid input 'VECTOR': expected "(", "allShortestPaths" or "shortestPath" (line 1, column 8 (offset: 7))
# "CREATE VECTOR INDEX $name IF NOT EXISTS FOR (n:disease) ON n.embeddings OPTIONS { indexConfig: { `vector.dimensions`: toInteger($dimensions), `vector.similarity_function`: $similarity_fn } }"
#         ^}
#
# The above exception was the direct cause of the following exception:
#
# Neo4jIndexError                           Traceback (most recent call last)
# Cell In[15], line 5
#       1 INDEX_NAME = "disease_embedding_index"
#       3 driver = GraphDatabase.driver(NEO4J_URI, auth=(NEO4J_USERNAME, NEO4J_PASSWORD))
# ----> 5 create_vector_index(
#       6     driver, INDEX_NAME,
#       7     label="disease",
#       8     embedding_property="embeddings",
#       9     dimensions=768,
#      10     similarity_fn="euclidean")
#      12 retriever = VectorRetriever(
#      13     driver,
#      14     index_name=INDEX_NAME,
#      15     embedder=embedder,
#      16     return_properties=["name","unique_id"],
#      17 )
#      19 print(f"Using index: {retriever.index_name}")
#
# File ~/miniconda3/envs/kg/lib/python3.10/site-packages/neo4j_graphrag/indexes.py:123, in create_vector_index(driver, name, label, embedding_property, dimensions, similarity_fn, fail_if_exists, neo4j_database)
#     117     driver.execute_query(
#     118         query,
#     119         {"name": name, "dimensions": dimensions, "similarity_fn": similarity_fn},
#     120         database_=neo4j_database,
#     121     )
#     122 except neo4j.exceptions.ClientError as e:
# --> 123     raise Neo4jIndexError(f"Neo4j vector index creation failed: {e.message}") from e
#
# Neo4jIndexError: Neo4j vector index creation failed: Invalid input 'VECTOR': expected "(", "allShortestPaths" or "shortestPath" (line 1, column 8 (offset: 7))
# "CREATE VECTOR INDEX $name IF NOT EXISTS FOR (n:disease) ON n.embeddings OPTIONS { indexConfig: { `vector.dimensions`: toInteger($dimensions), `vector.similarity_function`: $similarity_fn } }"
#         ^

# %%
# ------------------------基于类似文本搜索-------------------------
# Initialize the retriever
retriever = VectorRetriever(
    driver,
    index_name=INDEX_NAME,
    embedder=embedder,
    return_properties=["name","unique_id"],
)

query_text = "delirium"
retriever_result = retriever.search(query_text=query_text, top_k=5)

for result in retriever_result.items:
    print(result.content)

# %%
# ---------------------------------GraphRAG---------------------------------
rag = GraphRAG(retriever=retriever, llm=llm)

query_text = "what about relationship alzheimer's disease and delirium <think>\n\n</think>"
response = rag.search(query_text=query_text, retriever_config={"top_k": 5})
print(response.answer)

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

client = ChatNVIDIA(
  model="deepseek-ai/deepseek-r1",
  api_key="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", 
  temperature=0.6,
  top_p=0.7,
  max_tokens=4096,
)

for chunk in client.stream([{"role":"user","content":""}]): 
  print(chunk.content, end="")

# %%
# from langchain.chains import GraphCypherQAChain
# from langchain.prompts import PromptTemplate
# graph = Neo4jGraph(
#     url=NEO4J_URI,
#     username=NEO4J_USERNAME,
#     password=NEO4J_PASSWORD
# )
# graph.refresh_schema()

# CYPHER_GENERATION_TEMPLATE = """Task:Generate Cypher statement to query a graph database.
# Instructions:
# Use only the provided relationship types and properties in the schema.
# Do not use any other relationship types or properties that are not provided.
# Schema:
# {schema}
# Note: Do not include any explanations or apologies in your responses.
# Do not respond to any questions that might ask anything else than for you to construct a Cypher statement.
# Do not include any text except the generated Cypher statement.
# Examples: Here are a few examples of generated Cypher statements for particular questions:
# # How many people played in Top Gun?
# MATCH (m:Movie {{name:"Top Gun"}})<-[:ACTED_IN]-()
# RETURN count(*) AS numberOfActors

# The question is:
# {question}<think>\n\n</think>"""


# cypher_generation_prompt = PromptTemplate(
#     template=CYPHER_GENERATION_TEMPLATE,
#     input_variables=["question"],
# )

# cypher_chain = GraphCypherQAChain.from_llm(
#     llm=llm,
#     graph=graph,
#     validate_cypher=True,
#     cypher_prompt=cypher_generation_prompt,
#     verbose=True,
#     allow_dangerous_requests=True,
# )

# cypher_chain.invoke({'query': "What disease are associated with delirium?" })
# # cypher_chain.invoke({"query": "What are associated with delirium?","schema": graph.refresh_schema()})

# %%
# from neo4j_graphrag.retrievers import HybridRetriever

# INDEX_NAME = "embedding-name"
# FULLTEXT_INDEX_NAME = "fulltext-index-name"

# retriever = HybridRetriever(
#     driver,
#     INDEX_NAME,
#     FULLTEXT_INDEX_NAME,
#     embedder,
# )

# %%
# from neo4j_graphrag.retrievers import HybridCypherRetriever

# INDEX_NAME = "embedding-name"
# FULLTEXT_INDEX_NAME = "fulltext-index-name"

# retriever = HybridCypherRetriever(
#     driver,
#     INDEX_NAME,
#     FULLTEXT_INDEX_NAME,
#     retrieval_query="MATCH (node)-[:AUTHORED_BY]->(author:Author) RETURN author.name"
#     embedder=embedder,
# )

# %%
# from neo4j_graphrag.retrievers import HybridCypherRetriever

# INDEX_NAME = "embedding-name"
# FULLTEXT_INDEX_NAME = "fulltext-index-name"

# retriever = HybridCypherRetriever(
#     driver,
#     INDEX_NAME,
#     FULLTEXT_INDEX_NAME,
#     retrieval_query="MATCH (node)-[:AUTHORED_BY]->(author:Author) RETURN author.name"
#     embedder=embedder,
# )
